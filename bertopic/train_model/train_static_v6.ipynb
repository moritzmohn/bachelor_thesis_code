# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# !pip install bertopic
# Out:
# Collecting bertopic
#   Downloading bertopic-0.16.0-py2.py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.1/154.1 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.25.2)
# Collecting hdbscan>=0.8.29 (from bertopic)
#   Downloading hdbscan-0.8.33.tar.gz (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 65.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting umap-learn>=0.5.0 (from bertopic)
#   Downloading umap-learn-0.5.5.tar.gz (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.9/90.9 kB 12.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.2.2)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (4.66.2)
# Collecting sentence-transformers>=0.4.1 (from bertopic)
#   Downloading sentence_transformers-2.5.1-py3-none-any.whl (156 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.5/156.5 kB 21.1 MB/s eta 0:00:00
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (5.15.0)
# Collecting cython<3,>=0.27 (from hdbscan>=0.8.29->bertopic)
#   Using cached Cython-0.29.37-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.11.4)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2023.4)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (23.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.3.0)
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.38.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.1.0+cu121)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.20.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (9.4.0)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic) (0.58.1)
# Collecting pynndescent>=0.5 (from umap-learn>=0.5.0->bertopic)
#   Downloading pynndescent-0.5.11-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (4.10.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (0.41.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->bertopic) (1.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers>=0.4.1->bertopic) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers>=0.4.1->bertopic) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers>=0.4.1->bertopic) (0.4.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Building wheels for collected packages: hdbscan, umap-learn
#   Building wheel for hdbscan (pyproject.toml) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.33-cp310-cp310-linux_x86_64.whl size=3039289 sha256=49f539e243f27200d101d084f5fa611023a1fa68483961591e3a5657634b65e5
#   Stored in directory: /root/.cache/pip/wheels/75/0b/3b/dc4f60b7cc455efaefb62883a7483e76f09d06ca81cf87d610
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.5-py3-none-any.whl size=86832 sha256=86bb4105bcedaf383281ad1d181f33bcb9e0324572beb35d470b3e4a99e98757
#   Stored in directory: /root/.cache/pip/wheels/3a/70/07/428d2b58660a1a3b431db59b806a10da736612ebbc66c1bcc5
# Successfully built hdbscan umap-learn
# Installing collected packages: cython, pynndescent, hdbscan, umap-learn, sentence-transformers, bertopic
#   Attempting uninstall: cython
#     Found existing installation: Cython 3.0.9
#     Uninstalling Cython-3.0.9:
#       Successfully uninstalled Cython-3.0.9
# Successfully installed bertopic-0.16.0 cython-0.29.37 hdbscan-0.8.33 pynndescent-0.5.11 sentence-transformers-2.5.1 umap-learn-0.5.5

# %%
from bertopic import BERTopic
from hdbscan import HDBSCAN
from sklearn.feature_extraction.text import CountVectorizer
from bertopic.representation import PartOfSpeech
from bertopic.vectorizers import ClassTfidfTransformer
from bertopic.representation import MaximalMarginalRelevance
from sentence_transformers import SentenceTransformer
from umap import UMAP
import json
import spacy

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
with open("drive/MyDrive/data_ba/sorted_title_content_84-23_v6", "r") as fp:
        data_list = json.load(fp)

# %%
# !python -m spacy download de_core_news_sm
# Out:
# Collecting de-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/de_core_news_sm-3.7.0/de_core_news_sm-3.7.0-py3-none-any.whl (14.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 36.7 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from de-core-news-sm==3.7.0) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (2.6.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (1.25.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (2.1.5)
# Installing collected packages: de-core-news-sm
# Successfully installed de-core-news-sm-3.7.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('de_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
stopwords = []

with open("drive/MyDrive/data_ba/german_stopwords_plain.txt", "r") as file:

    for line in file:
        if not line.startswith(";"):
            stopwords.append(line[:-1])

# %%
def train_model(plain_texts, stopwords):

    sentence_model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')
    embeddings = sentence_model.encode(plain_texts, show_progress_bar=False)

    hdbscan_model = HDBSCAN(min_cluster_size=300, metric='euclidean', cluster_selection_method='eom', prediction_data=True)

    vectorizer_model = CountVectorizer(stop_words = stopwords, min_df=10)

    ctfidf_model = ClassTfidfTransformer(reduce_frequent_words=True)

    pos_patterns = [
            [{'POS': 'ADJ'}],
            [{'POS': 'NOUN'}],
            [{'POS': 'PROPN'}]
    ]

    mmr = MaximalMarginalRelevance(diversity=1.0)
    pos = PartOfSpeech("de_core_news_sm", pos_patterns=pos_patterns)
    representation_models = [pos, mmr]

    topic_model = BERTopic(low_memory=True,
                            hdbscan_model=hdbscan_model,
                            ctfidf_model=ctfidf_model,
                            representation_model=representation_models,
                            vectorizer_model=vectorizer_model)

    topics, probs = topic_model.fit_transform(plain_texts, embeddings)

    table = topic_model.get_topic_info()
    table.to_csv('drive/MyDrive/data_ba/model_84-23_topics_v6.csv')
    print(topic_model.get_topic_info())

    return topic_model

# %%
def save_model(topic_model):

    # Method 1 - safetensors
    embedding_model = "sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2"
    topic_model.save("drive/MyDrive/data_ba/static_model_84-23_v6", serialization="safetensors", save_ctfidf=True, save_embedding_model=embedding_model)

# %%
data_list.pop()

topic_model = train_model(data_list, stopwords)
save_model(topic_model)
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/4.12k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/471M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
#     Topic  Count                                               Name  \
# 0      -1  65230                      -1_neue_neuen_letzten_grossen
# 1       0  12022                           0_bmw_renault_neue_neuen
# 2       1   9386  1_verletzte_entgegenkommenden_verletzten_fahre...
# 3       2   8822                          2_neuen_neue_ersten_erste
# 4       3   7604               3_airlines_boeing_crossair_deutschen
# 5       4   4101                                   4_svp_sp_fdp_cvp
# 6       5   2763   5_russischen_russische_amerikanischen_irakischen
# 7       6   2744     6_angeklagte_angeklagten_verurteilte_bedingten
# 8       7   2679  7_gestohlen_unbekannte_gestohlenen_verfolgungs...
# 9       8   2290     8_unwetter_oberland_zahlreiche_schneebedeckten
# 10      9   2154                           9_neue_neuen_alten_leben
# 11     10   1804   10_brandstiftung_brennenden_brennende_unbekannte
# 12     11   1676         11_erlaubten_kontrollierten_fuhren_letzten
# 13     12   1545  12_verkehrsunfall_geriet_entgegenkommenden_fro...
# 14     13   1492                 13_blauen_blaue_ride_oberirdischen
# 15     14   1365    14_jugendlichen_erwachsenen_erwachsene_sicherer
# 16     15   1359                  15_gotthard_zweite_zweiten_langen
# 17     16    899          16_unternehmen_ersten_vergangenen_schweiz
# 18     17    879                    17_olympischen_de_olympische_km
# 19     18    879    18_verletzten_bfu_schwerverletzten_verunfallten
# 20     19    837                     19_motorisierten_neue_sp_neuen
# 21     20    737           20_parlement_publiques_recherche_justice
# 22     21    720                 21_verletzte_letzten_kinder_jungen
# 23     22    700   22_schwere_entgegenkommenden_verletzte_fahrenden
# 24     23    669                          23_bridge_neue_alte_neuen
# 25     24    566                 24_schumacher_runde_michael_runden
# 26     25    543                                  25_svp_fdp_sp_cvp
# 27     26    531  26_bilateralen_bilaterale_flankierenden_schwei...
# 28     27    522                         27_the_moderne_grossen_art
# 29     28    517                 28_bauliche_baulichen_tiefere_neue
# 30     29    513                29_velofahrenden_route_sichere_neue
# 31     30    506                 30_digitale_handy_digitalen_mobile
# 32     31    481  31_streikenden_staatlichen_streikende_angestel...
# 33     32    443  32_chinesischen_chinesische_chinesischer_kommu...
# 34     33    373                           33_tote_dpa_schweren_afp
# 35     34    355     34_infizierten_infizierte_schweiz_chinesischen
# 36     35    338           35_pd_kommenden_provisorische_schlechtem
# 37     36    331     36_behinderte_behinderten_sehbehinderte_blinde
#
#                                        Representation  \
# 0   [neue, neuen, letzten, grossen, ersten, grosse...
# 1   [bmw, renault, neue, neuen, ersten, km, ber, g...
# 2   [verletzte, entgegenkommenden, verletzten, fah...
# 3   [neuen, neue, ersten, erste, regionalen, reise...
# 4   [airlines, boeing, crossair, deutschen, neue, ...
# 5   [svp, sp, fdp, cvp, gp, politischen, politisch...
# 6   [russischen, russische, amerikanischen, irakis...
# 7   [angeklagte, angeklagten, verurteilte, bedingt...
# 8   [gestohlen, unbekannte, gestohlenen, verfolgun...
# 9   [unwetter, oberland, zahlreiche, schneebedeckt...
# 10  [neue, neuen, alten, leben, letzten, lange, er...
# 11  [brandstiftung, brennenden, brennende, unbekan...
# 12  [erlaubten, kontrollierten, fuhren, letzten, e...
# 13  [verkehrsunfall, geriet, entgegenkommenden, fr...
# 14  [blauen, blaue, ride, oberirdischen, neue, kos...
# 15  [jugendlichen, erwachsenen, erwachsene, sicher...
# 16  [gotthard, zweite, zweiten, langen, neuen, lan...
# 17  [unternehmen, ersten, vergangenen, schweiz, de...
# 18  [olympischen, de, olympische, km, ersten, letz...
# 19  [verletzten, bfu, schwerverletzten, verunfallt...
# 20  [motorisierten, neue, sp, neuen, sicherer, fdp...
# 21  [parlement, publiques, recherche, justice, pol...
# 22  [verletzte, letzten, kinder, jungen, weiss, ha...
# 23  [schwere, entgegenkommenden, verletzte, fahren...
# 24  [bridge, neue, alte, neuen, alten, lange, erst...
# 25  [schumacher, runde, michael, runden, ersten, z...
# 26  [svp, fdp, sp, cvp, kosten, budgetierten, lauf...
# 27  [bilateralen, bilaterale, flankierenden, schwe...
# 28  [the, moderne, grossen, art, grosse, alten, de...
# 29  [bauliche, baulichen, tiefere, neue, letzten, ...
# 30  [velofahrenden, route, sichere, neue, motorisi...
# 31  [digitale, handy, digitalen, mobile, elektroni...
# 32  [streikenden, staatlichen, streikende, angeste...
# 33  [chinesischen, chinesische, chinesischer, komm...
# 34  [tote, dpa, schweren, afp, tiefe, sda, verletz...
# 35  [infizierten, infizierte, schweiz, chinesische...
# 36  [pd, kommenden, provisorische, schlechtem, mot...
# 37  [behinderte, behinderten, sehbehinderte, blind...
#
#                                   Representative_Docs
# 0   [So können Sie von A bis Z sparen, ohne zu lei...
# 1   [Die Schöne ist kein Biest // "Der Yaris passt...
# 2   [Polizeinachrichten // [*] Am Samstag, 1. Juli...
# 3   [Zwischen Verständigungslösung und überrissene...
# 4   [Das Luftschloss ist gebaut // Überdimensionie...
# 5   [Nationalrat lässt Gewissensprüfung für den Zi...
# 6   [Kohle für Kolumbien // Die Verbrennung von St...
# 7   [Weggesperrt seit 27 Jahren // Der Bankräuber ...
# 8   [Zwei Autos gestohlen // Schlieren. - Am frühe...
# 9   [Schneechaos ohne Ende // Die Schweizer Berge ...
# 10  [Im Garten Italiens // Von Andreas W. Schmid (...
# 11  [«Es sah aus wie Bilder aus Pompeji» // Die Ka...
# 12  [Das wirkt verdächtig // Alchenflüh Warum gera...
# 13  [Frontalkollision in der Waadt fordert vier To...
# 14  [Gemeinden leiden unter dem Verkehr // Michael...
# 15  [Achtung, hier kommt der Pedibus // Von Bettin...
# 16  [«Die zweite Spur ist dann schnell freigegeben...
# 17  [Die monatliche Konjunkturanalyse der NZZ // "...
# 18  [«Ich bin ein Berner durch und durch» // Vom a...
# 19  [Der Velofahrer als Rowdy und Gesetzesbrecher ...
# 20  [Weiterer Schritt zum autofreien Limmatquai //...
# 21  [DIE ZUKUNFT DES VERKEHRS RUND UM DEN BAHNHOF ...
# 22  [«Viele Tierarten konnten nur mithilfe von Zoo...
# 23  [Motorradfahrer bei Unfall auf der A 53 schwer...
# 24  [Eine Wunderharfe über dem Wolkenmeer // Von M...
# 25  [Schumacher gegen Häkkinen - oder Ferrari gege...
# 26  [Staatsrechnung im Rekordtempo durchberaten //...
# 27  [Der Brückenschlag zum europäischen Binnenmark...
# 28  [Kunst im Löwenbräuareal - Rondinone, Orozco u...
# 29  [Was uns Tempo 30 innerorts brächte // Ziel de...
# 30  [SP fordert freie Fahrt für Velos // Die Linke...
# 31  [Der Spion im Hosensack // Datenhandel · Bei j...
# 32  [Frankreich zwischen Reform und Immobilismus /...
# 33  [Stadt im Umbruch // Der Wirtschaftsboom und d...
# 34  [Über 90 Tote bei Horrorunfall // Im Iran ist ...
# 35  [Die Welt hat die Seuche // Coronavirus Die US...
# 36  [Jetzt braucht es Nerven und Geduld // Baustel...
# 37  [Der Berner Bahnhof ist für Rollstuhlfahrer vo...
